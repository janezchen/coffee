# %% [markdown]
# # How much will coffee cost, tomorrow?

# %% [markdown]
# <img src="coffee.jpg">

# %% [markdown]
# Coffee is a relatable, lovable, two sided market. It serves as a cash crop for developing countries, providing a primary source of income for over 100 million people. In 2011 the coffee industry was valued at over 20 billion dollars, and coffee futures are traded on key finance exchanges every day alongside oil and gold.
#
# Coffee production occurs primarily in Brazil, Vietnam, Indonesia, and Columbia, with Brazil producing nearly twice as much coffee as Vietnam. Various beans are common to specific parts of the world, and hold different levels of value based on their perceived quality. Most of the world’s coffee industry, and therefore the price of coffee, is controlled by Kraft, Nestle, P&G, and Sara Lee. As one can see, there are a limited number of factors affecting the price of coffee as a commodity.
#
# Because coffee futures are publicly traded, there is a huge incentive to accurately model the future price of the good. Some of the factors worth considering are weather forecasting in countries of production, changes in demand, economics of export and import laws, and the price of raw materials. This information can be freely accessed and integrated into a predictive model.

# %% [markdown]
# #Table of Contents

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
import requests
import json

#get coffee price data for arabica and robusta
page_a = requests.get("https://www.quandl.com/api/v3/datasets/CEPEA/COFFEE_A.json", params={"start_date": "2002-01-01", "end_date": "2011-12-31", "order": "asc"})
page_r = requests.get("https://www.quandl.com/api/v3/datasets/CEPEA/COFFEE_R.json", params={"start_date": "2002-01-01", "end_date": "2011-12-31", "order": "asc"})

df = pd.DataFrame(page_a.json()["dataset"]["data"], columns=["date", "arabica_price"])
df['robusta_price'] = pd.DataFrame(page_r.json()["dataset"]["data"], columns=["date", "price"])["price"]

# %%
#gets quandl data from a specific url, using the set params for start and end dates
#using datecol and datacol, get data from the appropriate rows
def get_dailydatadict(url, datecol, datacol):
    page = requests.get(url, params={"start_date": "2002-01-01", "end_date": "2011-12-31", "order": "asc"})
    datadict = dict([(entry[datecol],entry[datacol]) for entry in page.json()["dataset"]["data"]])
    return datadict

def get_yearlydatadict(url, datecol, datacol):
    page = requests.get(url, params={"start_date": "2002-01-01", "end_date": "2011-12-31", "order": "asc"})
    datadict = dict([(int(entry[datecol].split("-")[0]),entry[datacol]) for entry in page.json()["dataset"]["data"]])
    return datadict

def match_dailydates(datadict):
    col = []
    data = np.nan
    for d in df["date"]:
        if d in datadict:
            data = datadict[d]
        col.append(data)
    return col

def match_yearlydates(datadict):
    col = []
    data = np.nan
    for d in df["date"]:
        yr = int(d.split("-")[0])
        if yr in datadict:
            data = datadict[yr]
        col.append(data)
    return col

# %%
##daily indexes
#arabica futures
df["futures_price"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/CHRIS/ICE_KC2.json", 0, 1))
#global nasdaq index
df["nasdaq"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/NASDAQOMX/NQGI.json?end_date=2015-12-02", 0, 1))
#brazil equities index
df["brazil_equities"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/NASDAQOMX/NQBRBRL.json?auth_token=YQyb9APWhhBMsRuWHckr&end_date=2015-12-02", 0, 1))
#cattle price
df["cattle_price"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/CEPEA/CATTLE.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#soybean prices
df["soybean_price"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/CEPEA/SOYBEAN.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#cotton prices
df["cotton_price"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/CEPEA/COTTON.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#orange prices
df["orange_price"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/CEPEA/CITRUS_T.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#exchange rate with US
df["USD_exchange"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/CURRFX/BRLUSD.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#exchange rate with EU
df["Euro_exchange"] = match_dailydates(get_dailydatadict("https://www.quandl.com/api/v3/datasets/BUNDESBANK/BBEX3_D_BRL_EUR_BB_AC_000.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))

# %%
#annual Brazil production info
page_prod = requests.get("https://www.quandl.com/api/v3/datasets/BCB/1262.json", params={"start_date": "2001-12-31", "end_date": "2010-12-31", "order": "asc"})
prod_df = pd.DataFrame(page_prod.json()["dataset"]["data"], columns=["year", "prv year prod"])
prod_df["year"] = [int(yr.split("-")[0]) + 1 for yr in prod_df["year"]]
df["prev_prod"] = match_yearlydates(dict(zip(prod_df["year"], prod_df["prv year prod"])))

# %%
##annual data
#Brazil production
df["prod"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/BCB/1262.json", 0, 1))
#Brazil government effectiveness (World Bank Governance Indicators)
df["gov"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WWGI/BRA_GE_EST.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#Brazil regulation effectiveness (World Bank Governance Indicators)
df["regulations"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WWGI/BRA_RQ_EST.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#investment in Brazil
df["investment"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/OECD/MEI_BOP_BPFADI03_BRA_CXCU_A.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#poor in Brazil living below $5/day
df["poor"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WPOV/BRA_SI_POV_NOP5.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#Brazil population
df["population"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WRI/SOCIO_WORLD_BRAZIL.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#Brazil GDP
df["GDP"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WRI/SOCIO_WORLD_BRAZIL.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 3))
#Brazil energy use
df["energy"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WRI/SOCIO_WORLD_BRAZIL.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 4))
#Brazil exports
df["exports"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/UIFS/BP_EVO_BRA.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#Brazil inbound tourism
df["inbound_tourism"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/UTOR/INTUR_BRA.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#Brazil outbound tourism
df["outbound_tourism"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/UTOR/EXTUR_BRA.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))
#Brazil graduates in agriculture
df["agri_grads"] = match_yearlydates(get_yearlydatadict("https://www.quandl.com/api/v3/datasets/WEDU/BRA_UIS_G_56_F600_DCOUNT.json?auth_token=YQyb9APWhhBMsRuWHckr", 0, 1))

# %%
df["nasdaq"] = [x/10. for x in df["nasdaq"]]
df["brazil_equities"] = [x/10. for x in df["brazil_equities"]]
df["population"] = [x/1000000. for x in df["population"]]
df["GDP"] = [x/1000. for x in df["GDP"]]
df["prev_prod"] = [x/1000. for x in df["prev_prod"]]
df["energy"] = [x/1000. for x in df["energy"]]
df.head()
# Out:
#          date  arabica_price  robusta_price  futures_price  nasdaq  brazil_equities  cattle_price  soybean_price  cotton_price  orange_price  USD_exchange  Euro_exchange  prev_prod       gov  regulations  investment       poor  population     GDP    energy  exports  inbound_tourism  outbound_tourism  agri_grads     prod
# 0  2002-01-02      45.473090      21.532118          49.25  6.8665           2.3683         20.02      11.115451         38.32          5.11      0.435024         2.0862   3.639138  0.033562     0.286739    16590.21  90.037732    0.000179  0.0008  0.195759  74.4624             3785              2338        8780  2610524
# 1  2002-01-03      46.165577      21.607843          49.30  6.9342           2.4343         20.13      11.145969         38.47          5.13      0.436446         2.0729   3.639138  0.033562     0.286739    16590.21  90.037732    0.000179  0.0008  0.195759  74.4624             3785              2338        8780  2610524
# ...

# %%
#plot daily data
daily = ['arabica_price','robusta_price', 'futures_price', 'nasdaq', 'brazil_equities', 'cattle_price', 'soybean_price', 'cotton_price', 'orange_price', 'USD_exchange', 'Euro_exchange']
df.loc[:,daily].plot()

# %%
#plot yearly data
yearly = df.columns.difference(daily)
df.loc[:, yearly].plot()

# %%
f, ax = plt.subplots(4, 3, figsize=(20,30))
ax = ax.flatten()

for i in xrange(1,len(daily)):
    sns.regplot(x=daily[i], y="arabica_price", data=df, ax = ax[i-1])

# %%
f, ax = plt.subplots(5, 3, figsize=(20,30))
ax = ax.flatten()

for i in xrange(0,len(yearly)):
    sns.regplot(x=yearly[i], y="arabica_price", data=df, ax = ax[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-f8dd3fd535e0> in <module>()
#       3
#       4 for i in xrange(0,len(yearly)):
# ----> 5     sns.regplot(x=yearly[i], y="arabica_price", data=df, ax = ax[i])
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     770     scatter_kws["marker"] = marker
#     771     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 772     plotter.plot(ax, scatter_kws, line_kws)
#     773     return ax
#     774
#
# //anaconda/lib/python2.7/site-packages/seaborn/linearmodels.pyc in plot(self, ax, scatter_kws, line_kws)
# ...

# %%
import statsmodels.api as sm
from statsmodels.formula.api import glm, ols
ols_model = ols('arabica_price ~ cattle_price + soybean_price + orange_price + cotton_price', df).fit()
ols_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          arabica_price   R-squared:                       0.853
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     3614.
# Date:                Tue, 08 Dec 2015   Prob (F-statistic):               0.00
# Time:                        10:44:04   Log-Likelihood:                -11732.
# No. Observations:                2493   AIC:                         2.347e+04
# Df Residuals:                    2488   BIC:                         2.350e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------
# ...
